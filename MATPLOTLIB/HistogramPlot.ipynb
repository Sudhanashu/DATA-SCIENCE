# %%
#HISTOGRAM PLOT

import matplotlib.pyplot as plt
import numpy as np
import random
x=np.random.randint(10,60,(50))
print(x)
# Out:
# [54 18 29 54 36 41 46 14 28 17 31 29 35 59 31 28 59 33 49 34 40 54 45 32
#  32 51 32 10 16 10 44 43 29 20 20 42 14 10 41 50 48 14 57 32 17 39 49 45
#  39 10]

# %%
no = [54,18,29,54,36,41,46,14,28,17,31,29,35,59,31,28,59,33,49,34,40,54,45,32
 ,32,51,32,10,16,10,44,43,29,20,20,42,14,10,41,50,48,14,57,32,17,39,49,45,39,10]

plt.hist(no)

plt.title("Wscube")
plt.xlabel("Python")
plt.ylabel("No")
plt.show()

# %%
#COLOR

no = [54,18,29,54,36,41,46,14,28,17,31,29,35,59,31,28,59,33,49,34,40,54,45,32
 ,32,51,32,10,16,10,44,43,29,20,20,42,14,10,41,50,48,14,57,32,17,39,49,45,39,10]

plt.hist(no,color="g")

plt.title("Wscube")
plt.xlabel("Python")
plt.ylabel("No")
plt.show()

# %%
#EDGECOLOR

no = [54,18,29,54,36,41,46,14,28,17,31,29,35,59,31,28,59,33,49,34,40,54,45,32
 ,32,51,32,10,16,10,44,43,29,20,20,42,14,10,41,50,48,14,57,32,17,39,49,45,39,10]

plt.hist(no,color="g",edgecolor="r")

plt.title("Wscube")
plt.xlabel("Python")
plt.ylabel("No")
plt.show()

# %%
#BINS PARAMETERS

no = [54,18,29,54,36,41,46,14,28,17,31,29,35,59,31,28,59,33,49,34,40,54,45,32
 ,32,51,32,10,16,10,44,43,29,20,20,42,14,10,41,50,48,14,57,32,17,39,49,45,39,10]

l=[10,20,30,40,50,60]
plt.hist(no,color="g",bins=l,edgecolor="r")

plt.title("Wscube")
plt.xlabel("Python")
plt.ylabel("No")
plt.show()

# %%
#RANGE PARAMETERS

no = [54,18,29,54,36,41,46,14,28,17,31,29,35,59,31,28,59,33,49,34,40,54,45,32
 ,32,51,32,10,16,10,44,43,29,20,20,42,14,10,41,50,48,14,57,32,17,39,49,45,39,10]

l=[10,20,30,40,50,60]
plt.hist(no,"auto",(0,100),edgecolor="r")

plt.title("Wscube")
plt.xlabel("Python")
plt.ylabel("No")
plt.show()

# %%
#BUTTOM PARAMETERS

no = [54,18,29,54,36,41,46,14,28,17,31,29,35,59,31,28,59,33,49,34,40,54,45,32
 ,32,51,32,10,16,10,44,43,29,20,20,42,14,10,41,50,48,14,57,32,17,39,49,45,39,10]

l=[10,20,30,40,50,60]
plt.hist(no,color="r",edgecolor="g",bottom=10)

plt.title("Wscube")
plt.xlabel("Python")
plt.ylabel("No")
plt.show()

# %%
#ALIGN PARAMETERS

no = [54,18,29,54,36,41,46,14,28,17,31,29,35,59,31,28,59,33,49,34,40,54,45,32
 ,32,51,32,10,16,10,44,43,29,20,20,42,14,10,41,50,48,14,57,32,17,39,49,45,39,10]

l=[10,20,30,40,50,60]
plt.hist(no,color="r",edgecolor="b",bottom=10,align="left")

plt.title("Wscube")
plt.xlabel("Python")
plt.ylabel("No")
plt.show()

# %%
#HISTOGRAM TYPE PARAMETERS

no = [54,18,29,54,36,41,46,14,28,17,31,29,35,59,31,28,59,33,49,34,40,54,45,32
 ,32,51,32,10,16,10,44,43,29,20,20,42,14,10,41,50,48,14,57,32,17,39,49,45,39,10]

l=[10,20,30,40,50,60]
plt.hist(no,color="r",edgecolor="b",bottom=10,align="left",histtype="step")

plt.title("Wscube")
plt.xlabel("Python")
plt.ylabel("No")
plt.show()

# %%
#ORIENTATION PARAMETERS

no = [54,18,29,54,36,41,46,14,28,17,31,29,35,59,31,28,59,33,49,34,40,54,45,32
 ,32,51,32,10,16,10,44,43,29,20,20,42,14,10,41,50,48,14,57,32,17,39,49,45,39,10]

l=[10,20,30,40,50,60]
plt.hist(no,color="r",bins=l,edgecolor="b",orientation="horizontal")

plt.title("Wscube")
plt.xlabel("Python")
plt.ylabel("No")
plt.show()

# %%
#WIDTH PARAMETERS

no = [54,18,29,54,36,41,46,14,28,17,31,29,35,59,31,28,59,33,49,34,40,54,45,32
 ,32,51,32,10,16,10,44,43,29,20,20,42,14,10,41,50,48,14,57,32,17,39,49,45,39,10]

l=[10,20,30,40,50,60]
plt.hist(no,color="r",bins=l,edgecolor="b",orientation="vertical",rwidth=0.8)

plt.title("Wscube")
plt.xlabel("Python")
plt.ylabel("No")
plt.show()

# %%
#LOG PARAMETERS

no = [54,18,29,54,36,41,46,14,28,17,31,29,35,59,31,28,59,33,49,34,40,54,45,32
 ,32,51,32,10,16,10,44,43,29,20,20,42,14,10,41,50,48,14,57,32,17,39,49,45,39,10]

l=[10,20,30,40,50,60]
plt.hist(no,color="r",bins=l,edgecolor="b",orientation="vertical",rwidth=0.8,log="True")

plt.title("Wscube")
plt.xlabel("Python")
plt.ylabel("No")
plt.show()

# %%
#LABEL PARAMETERS

no = [54,18,29,54,36,41,46,14,28,17,31,29,35,59,31,28,59,33,49,34,40,54,45,32
 ,32,51,32,10,16,10,44,43,29,20,20,42,14,10,41,50,48,14,57,32,17,39,49,45,39,10]

l=[10,20,30,40,50,60]
plt.hist(no,color="r",bins=l,edgecolor="b",orientation="vertical",rwidth=0.8,log="True",label="Python")

plt.title("Wscube")
plt.xlabel("Python")
plt.ylabel("No")
plt.legend()
plt.show()

# %%
#AXV PARAMETERS

no = [54,18,29,54,36,41,46,14,28,17,31,29,35,59,31,28,59,33,49,34,40,54,45,32
 ,32,51,32,10,16,10,44,43,29,20,20,42,14,10,41,50,48,14,57,32,17,39,49,45,39,10]

l=[10,20,30,40,50,60]
plt.hist(no,color="r",bins=l,edgecolor="b",orientation="vertical",rwidth=0.8,log="True",label="Python")

plt.title("Wscube")
plt.xlabel("Python")
plt.ylabel("No")

plt.axvline(45,color="g",label="line")

plt.legend()
plt.show()

# %%
#GRID PARAMETERS

no = [54,18,29,54,36,41,46,14,28,17,31,29,35,59,31,28,59,33,49,34,40,54,45,32
 ,32,51,32,10,16,10,44,43,29,20,20,42,14,10,41,50,48,14,57,32,17,39,49,45,39,10]

l=[10,20,30,40,50,60]
plt.hist(no,color="r",bins=l,edgecolor="b",orientation="vertical",rwidth=0.8,log="True",label="Python")

plt.title("Wscube")
plt.xlabel("Python")
plt.ylabel("No")

plt.axvline(45,color="g",label="line")

plt.grid()
plt.legend()
plt.show()
