# %%
import matplotlib.pyplot as plt

x=[1,2,3,4]
y=[1,2,3,4]
plt.plot(x,y,color="r")

plt.pie([1],colors="r")

x1=[10,20,30,40]
plt.pie(x)


plt.show()

# %%
x2=["a","s","d","f"]
y2=[10,20,30,40]
plt.bar(x2,y2)

plt.show()

# %%
x=[1,2,3,4]
y=[1,2,3,4]
plt.subplot(2,2,1)
plt.plot(x,y,color="r")

plt.subplot(2,2,2)
plt.pie(x,y,color="r")

x1=[10,20,30,40]
plt.subplot(2,2,3)
plt.pie(x)

x2=["a","s","d","f"]
y2=[10,20,30,40]
plt.subplot(2,2,4)
plt.bar(x2,y2)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 7
#       4 plt.plot(x,y,color="r")
#       6 plt.subplot(2,2,2)
# ----> 7 plt.pie(x,y,color="r")
#       9 x1=[10,20,30,40]
#      10 plt.subplot(2,2,3)
#
# TypeError: pie() got an unexpected keyword argument 'color'
